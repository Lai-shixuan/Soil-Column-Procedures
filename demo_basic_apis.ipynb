# %%
import API_functions.file_single as single
import API_functions.file_batch as batch
import API_functions.image_info as info

# %% [markdown]
# # 1. For single image processing

# %%
path_RGB = "d://6 Downloads//temp/PixPin_2024-05-08_12-56-12.jpg"
image = single.read_image_opencv(path_RGB)
single.show_image(image)
# Out:
# Reading Completed!

# %%
path_gray = "d://6 Downloads//temp/PixPin_2024-05-08_12-56-12-gray.jpg"
image = single.read_image_opencv(path_gray)
single.show_image(image)
# Out:
# Reading Completed!

# %%
save_name = "temp"
save_path = "d: /6 Downloads/temp/output/"
single.save_image(image, save_path, save_name, "png")
# Out:
# Saving Completed!

# %% [markdown]
# # 2. For batch image processing

# %%
# get an instance of batch.ImageName class
read_image_names = batch.ImageName(prefix="", suffix="")
output_image_names = batch.ImageName("output_test", "")

image_names = batch.get_image_names("e:/0101/Reconstruct/", read_image_names, "bmp")
image_lists = batch.read_images(image_names, gray=True, read_all=False, read_num=300)
batch.output_images(image_lists, "d:/6 Downloads/temp/output/", output_image_names, "png")
# Out:
# Your image name format is: _XXXX
# Your image name format is: output_test_XXXX
# 2641 images have been found in e:/0101/Reconstruct/
# The first 3 images are:
# e:/0101/Reconstruct\ou-1_rec00000623.bmp
# e:/0101/Reconstruct\ou-1_rec00000624.bmp
# e:/0101/Reconstruct\ou-1_rec00000625.bmp
# Warning, your files are too large to read all.
# Get names completely!
# 100%|██████████| 300/300 [00:01<00:00, 226.87it/s]
# first 300 images have been read
# if you want to read all, please set read_all=True
# Reading completely!
# 100%|██████████| 300/300 [00:06<00:00, 44.92it/s]
# 300 images have been saved to d:/6 Downloads/temp/output/ with the format png
# Output completely!

# %% [markdown]
# # 3. For single image information

# %%
image = single.read_image_opencv(path_gray)
info.get_info(image)
# Out:
# Reading Completed!
# Image size: (1020, 1920)
# Image is grayscale, not binary image
# Getting information completed!

# %%
hist = info.calculate_hist(image)
info.plot_hist(hist)

# %%
info.calculate_pore_percentage(image)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 info.calculate_pore_percentage(image)
#
# File ~\1_Codes\Image_processing_toolchain\API_functions\image_info.py:57, in calculate_pore_percentage(image)
#      55     raise Exception('Error: The image is not a grayscale image')
#      56 elif is_binary_image(image) is False:
# ---> 57     raise Exception('Error: The image is not a binary image')
#      58 else:
#      59     pore = 0
#
# Exception: Error: The image is not a binary image

# %% [markdown]
# # 4. For batch image format transformation
# This function will not read all image at once. It read one image and save it so no need to worry about memory issue, which means it is a **faster** function if you only want to **transform the format**.
#
# It only suits for grayscale images.

# %%
batch.format_transformer(image_name_lists=image_names, output_folder="d:/6 Downloads/temp/output/", my_image_name=output_image_names, output_format="png", read_all=False, read_num=1000)
# Out:
# 100%|██████████| 1000/1000 [02:00<00:00,  8.27it/s]
# first 1000 images have been saved to d:/6 Downloads/temp/output/ with the format png
# Output completely!
